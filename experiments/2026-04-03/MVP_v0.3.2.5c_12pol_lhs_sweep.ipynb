# %% [markdown]
# # MVP v0.3.2.5c -- Alpha x Lambda LHS Sweep (12 Policies)
#
# **Builds on:** v0.3.2.5b (6-policy LHS sweep) + v0.2.5.14e (12-policy action sweep)
#
# **Goal:** Same 15-point Maximin LHS design over alpha in [0.1, 0.5], lam/alpha in [0, 1]
# as v0.3.2.5b, but evaluated on all 12 target policies from v0.2.5.14e.
# Tests whether the (alpha, ratio) landscape changes with more policies and
# whether negative guidance helps ranking on the harder 12-policy set.
#
# Formula: `guide = alpha * target_grad - lam * behavior_grad`
#
# - `alpha` scales positive guidance (target policy)
# - `lam` scales negative guidance (behavior policy), where `lam = ratio * alpha`
# - `ratio = lam/alpha` in [0, 1] keeps negative proportional to positive
#
# **Behavior policy:** BCGaussian (trained on same 200 demos + 50 rollouts as chunk diffuser)

# %%
# %matplotlib inline
import sys, os, importlib
import numpy as np
import torch
import torch.nn as nn
import h5py, json, math, time
import matplotlib.pyplot as plt
from pathlib import Path
from scipy import stats

PROJECT_ROOT = Path("/home1/reishuen/latent_sope")
sys.path.insert(0, str(PROJECT_ROOT))
sys.path.insert(0, str(PROJECT_ROOT / "src"))
sys.path.insert(0, str(PROJECT_ROOT / "third_party" / "sope"))
sys.path.insert(0, str(PROJECT_ROOT / "third_party" / "robomimic"))

from opelab.core.baselines.diffusion.temporal import TemporalUnet
from opelab.core.baselines.diffusion.diffusion import GaussianDiffusion
from opelab.core.baselines.diffusion.helpers import EMA, apply_conditioning
import robomimic.utils.file_utils as FileUtils
import robomimic.utils.obs_utils as ObsUtils

import latent_sope.robomimic_interface.guidance as _guidance_mod
importlib.reload(_guidance_mod)
from latent_sope.robomimic_interface.checkpoints import (
    load_checkpoint, build_algo_from_checkpoint
)
from latent_sope.robomimic_interface.guidance import RobomimicDiffusionScorer

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")

# Paths
CKPT_BASE = PROJECT_ROOT / "third_party/robomimic/diffusion_policy_trained_models"
DEMO_HDF5 = PROJECT_ROOT / "third_party/robomimic/datasets/lift/ph/low_dim_v15.hdf5"
TARGET_ROLLOUT_DIR = PROJECT_ROOT / "rollouts" / "target_policy_50"
DIFFUSION_SAVE_DIR = PROJECT_ROOT / "diffusion_ckpts" / "mvp_v0252_traj_mse"
BEHAVIOR_SAVE_DIR = PROJECT_ROOT / "diffusion_ckpts" / "mvp_v0214_fixed_guidance"
ORACLE_JSON = PROJECT_ROOT / "results/2026-03-12/oracle_eval_all_checkpoints.json"
OBS_KEYS = ["object", "robot0_eef_pos", "robot0_eef_quat", "robot0_gripper_qpos"]

STATE_DIM = 19
ACTION_DIM = 7
TRANSITION_DIM = 26
CUBE_Z_INDEX = 2
LIFT_THRESHOLD = 0.84
CHUNK_SIZE = 4
N_DIFFUSION_STEPS = 256
BASE_DIM = 32
DIM_MULTS = (1, 4, 8)
ACTION_WEIGHT = 5.0
NUM_SYNTHETIC = 50
T_GEN = 60
GAMMA = 1.0
SCORE_TIMESTEP = 5
SIGMOID_SHARPNESS = 150.0

# Guidance config -- LHS sweep over (alpha, ratio) space
# 15-point Maximin Latin Hypercube: alpha in [0.1, 0.5], ratio (lam/alpha) in [0, 1]
# Generated with scipy.stats.qmc.LatinHypercube, seed optimized over 5000 draws
DESIGN_POINTS = [
    # (alpha, ratio) -> lam = alpha * ratio
    (0.14, 0.00),
    (0.11, 0.65),
    (0.15, 0.16),
    (0.18, 0.30),
    (0.22, 0.90),
    (0.24, 0.41),
    (0.26, 0.53),
    (0.29, 0.68),
    (0.33, 0.23),
    (0.35, 0.79),
    (0.38, 0.11),
    (0.42, 0.35),
    (0.42, 0.97),
    (0.47, 0.82),
    (0.49, 0.50),
]

TARGET_POLICIES = [
    {"name": "50demos_epoch10",  "dir": "lift_diffusion_50demos/20260311134204",  "ckpt": "models/model_epoch_10.pth"},
    {"name": "10demos_epoch10",  "dir": "lift_diffusion_10demos/20260311115828",  "ckpt": "models/model_epoch_10.pth"},
    {"name": "200demos_epoch10", "dir": "lift_diffusion_200demos/20260311141036", "ckpt": "models/model_epoch_10.pth"},
    {"name": "200demos_epoch20", "dir": "lift_diffusion_200demos/20260311141036", "ckpt": "models/model_epoch_20.pth"},
    {"name": "100demos_epoch20", "dir": "lift_diffusion_100demos/20260311135551", "ckpt": "models/model_epoch_20.pth"},
    {"name": "test_checkpoint",  "dir": "test/20260309132349",                   "ckpt": "last.pth"},
    {"name": "50demos_epoch20",  "dir": "lift_diffusion_50demos/20260311134204",  "ckpt": "models/model_epoch_20.pth"},
    {"name": "10demos_epoch30",  "dir": "lift_diffusion_10demos/20260311115828",  "ckpt": "models/model_epoch_30.pth"},
    {"name": "100demos_epoch30", "dir": "lift_diffusion_100demos/20260311135551", "ckpt": "models/model_epoch_30.pth"},
    {"name": "50demos_epoch30",  "dir": "lift_diffusion_50demos/20260311134204",  "ckpt": "models/model_epoch_30.pth"},
    {"name": "50demos_epoch40",  "dir": "lift_diffusion_50demos/20260311134204",  "ckpt": "models/model_epoch_40.pth"},
    {"name": "200demos_epoch40", "dir": "lift_diffusion_200demos/20260311141036", "ckpt": "models/model_epoch_40.pth"},
]

print(f"LHS design: {len(DESIGN_POINTS)} points in alpha=[0.1,0.5] x ratio=[0,1]")
print(f"{len(TARGET_POLICIES)} policies x {len(DESIGN_POINTS)} design points = {len(TARGET_POLICIES)*len(DESIGN_POINTS)} guided runs")
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# Loading weights:   0%|          | 0/197 [00:00<?, ?it/s]
# CLIPTextModelWithProjection LOAD REPORT from: openai/clip-vit-large-patch14
# Key                                                            | Status     |  |
# ---------------------------------------------------------------+------------+--+-
# vision_model.pre_layrnorm.bias                                 | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.mlp.fc1.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.mlp.fc2.bias              | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.q_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.v_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.k_proj.weight   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.q_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.layer_norm1.weight        | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.out_proj.bias   | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.layer_norm2.bias          | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.mlp.fc1.weight            | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.k_proj.bias     | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.out_proj.weight | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.layer_norm1.bias          | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.layer_norm2.weight        | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.self_attn.v_proj.bias     | UNEXPECTED |  |
# visual_projection.weight                                       | UNEXPECTED |  |
# vision_model.post_layernorm.weight                             | UNEXPECTED |  |
# vision_model.encoder.layers.{0...23}.mlp.fc2.weight            | UNEXPECTED |  |
# text_model.embeddings.position_ids                             | UNEXPECTED |  |
# vision_model.embeddings.position_embedding.weight              | UNEXPECTED |  |
# logit_scale                                                    | UNEXPECTED |  |
# vision_model.embeddings.position_ids                           | UNEXPECTED |  |
# vision_model.pre_layrnorm.weight                               | UNEXPECTED |  |
# vision_model.embeddings.patch_embedding.weight                 | UNEXPECTED |  |
# vision_model.embeddings.class_embedding                        | UNEXPECTED |  |
# vision_model.post_layernorm.bias                               | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Device: cuda
# LHS design: 15 points in alpha=[0.1,0.5] x ratio=[0,1]
# 12 policies x 15 design points = 180 guided runs

# %%
# ── Reward + OPE functions ──
def hard_reward(cube_z):
    return (cube_z > LIFT_THRESHOLD).astype(np.float32)

def sigmoid_reward(cube_z, center=LIFT_THRESHOLD, sharpness=SIGMOID_SHARPNESS):
    return (1.0 / (1.0 + np.exp(-sharpness * (cube_z - center)))).astype(np.float32)

def compute_ope_hard(states, gamma=1.0):
    cube_z = states[:, :, CUBE_Z_INDEX]
    return (hard_reward(cube_z) * (gamma ** np.arange(states.shape[1]))[None, :]).sum(axis=1)

def compute_ope_sigmoid(states, gamma=1.0):
    cube_z = states[:, :, CUBE_Z_INDEX]
    return (sigmoid_reward(cube_z) * (gamma ** np.arange(states.shape[1]))[None, :]).sum(axis=1)

def compute_sr_hard(states):
    cube_z = states[:, :, CUBE_Z_INDEX]
    return np.mean([np.any(cube_z[j] > LIFT_THRESHOLD) for j in range(states.shape[0])])

print("Functions defined.")
# Out:
# Functions defined.

# %%
# ── Load oracle ──
with open(ORACLE_JSON, "r") as f:
    oracle_all = json.load(f)

oracle_sr_map = {}
for pol in TARGET_POLICIES:
    name = pol["name"]
    if name == "test_checkpoint":
        with open(CKPT_BASE / "test/20260309132349/oracle_50.json", "r") as f:
            test_oracle = json.load(f)
        oracle_sr_map[name] = float(test_oracle["mean_return"])
    else:
        oracle_sr_map[name] = float(oracle_all[name]["mean_return"])

print("Oracle SR:")
for name, sr in sorted(oracle_sr_map.items(), key=lambda x: x[1]):
    print(f"  {name:<22} {sr*100:>5.0f}%")
# Out:
# Oracle SR:
#   50demos_epoch10            0%
#   10demos_epoch10            8%
#   200demos_epoch10          18%
#   200demos_epoch20          24%
#   100demos_epoch20          42%
#   test_checkpoint           54%
#   50demos_epoch20           60%
#   10demos_epoch30           62%
#   100demos_epoch30          72%
#   50demos_epoch30           82%
#   50demos_epoch40           88%
#   200demos_epoch40          90%

# %%
# ── Load data + normalization + diffuser ──
all_states_list, all_actions_list = [], []
target_data = []
for path in sorted(TARGET_ROLLOUT_DIR.glob("rollout_*.h5"))[:50]:
    with h5py.File(path, "r") as f:
        latents = f["latents"][:]
        actions = f["actions"][:]
    states = (latents[:, -1, :] if latents.ndim == 3 else latents).astype(np.float32)
    actions = actions.astype(np.float32)
    target_data.append({"states": states, "actions": actions})
    all_states_list.append(states)
    all_actions_list.append(actions)

with h5py.File(DEMO_HDF5, "r") as f:
    for dk in sorted(f["data"].keys(), key=lambda x: int(x.split("_")[1])):
        demo = f[f"data/{dk}"]
        states = np.concatenate([demo["obs"][k][:].astype(np.float32) for k in OBS_KEYS], axis=-1)
        actions = demo["actions"][:].astype(np.float32)
        all_states_list.append(states)
        all_actions_list.append(actions)

all_states = np.concatenate(all_states_list, axis=0)
all_actions = np.concatenate(all_actions_list, axis=0)
norm_mean = np.concatenate([all_states.mean(0), all_actions.mean(0)]).astype(np.float32)
norm_std = np.maximum(np.concatenate([all_states.std(0), all_actions.std(0)]), 1e-6).astype(np.float32)
norm_mean_t = torch.tensor(norm_mean, device=device)
norm_std_t = torch.tensor(norm_std, device=device)
normalize_fn = lambda x: (x - norm_mean_t) / norm_std_t
unnormalize_fn = lambda x: x * norm_std_t + norm_mean_t

initial_states_t = torch.tensor(
    np.array([ep["states"][0] for ep in target_data[:NUM_SYNTHETIC]]),
    dtype=torch.float32, device=device
)

temporal_model = TemporalUnet(
    horizon=CHUNK_SIZE, transition_dim=TRANSITION_DIM,
    dim=BASE_DIM, dim_mults=DIM_MULTS, attention=False,
).to(device)
diffusion_model = GaussianDiffusion(
    model=temporal_model, horizon=CHUNK_SIZE,
    observation_dim=STATE_DIM, action_dim=ACTION_DIM,
    n_timesteps=N_DIFFUSION_STEPS,
    normalizer=normalize_fn, unnormalizer=unnormalize_fn,
    predict_epsilon=False, loss_type="l2",
    clip_denoised=False, action_weight=ACTION_WEIGHT,
).to(device)
ema = EMA(diffusion_model)
ema.ema_model.load_state_dict(
    torch.load(DIFFUSION_SAVE_DIR / "diffusion_model_ema.pt", map_location=device)
)
print(f"Loaded diffuser. Initial states: {initial_states_t.shape}")
# Out:
# [ models/temporal ] Channel dimensions: [(26, 32), (32, 128), (128, 256)]
# [(26, 32), (32, 128), (128, 256)]
# /home1/reishuen/latent_sope/third_party/sope/opelab/core/baselines/diffusion/diffusion.py:314: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   betas * np.sqrt(alphas_cumprod_prev) / (1. - alphas_cumprod))
# Loaded diffuser. Initial states: torch.Size([50, 19])

# %%
# ── Load BCGaussian behavior policy ──
class BCGaussian(nn.Module):
    """Simple BC policy with Gaussian output for SOPE-style guidance."""
    def __init__(self, state_dim, action_dim, hidden_dim=256):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(state_dim, hidden_dim), nn.ReLU(),
            nn.Linear(hidden_dim, hidden_dim), nn.ReLU(),
        )
        self.mean_head = nn.Linear(hidden_dim, action_dim)
        self.log_std_head = nn.Linear(hidden_dim, action_dim)

    def forward(self, state):
        h = self.net(state)
        return self.mean_head(h), self.log_std_head(h).clamp(-5, 2)

    def log_prob(self, state, action):
        mean, log_std = self.forward(state)
        std = torch.exp(log_std)
        return -0.5 * (((action - mean) / std) ** 2 + 2 * log_std + math.log(2 * math.pi)).sum(dim=-1)

    def grad_log_prob(self, state, action):
        """Analytic gradient: -(a - mu) / sigma^2."""
        with torch.no_grad():
            mean, log_std = self.forward(state)
            std = torch.exp(log_std)
            return -(action - mean) / (std ** 2)

    def grad_log_prob_chunk(self, states, actions):
        B, T, _ = states.shape
        return self.grad_log_prob(
            states.reshape(B * T, -1), actions.reshape(B * T, -1)
        ).reshape(B, T, -1)

behavior_policy = BCGaussian(STATE_DIM, ACTION_DIM, hidden_dim=256).to(device)
behavior_policy.load_state_dict(
    torch.load(BEHAVIOR_SAVE_DIR / "bc_behavior.pt", map_location=device)
)
behavior_policy.eval()

# Sanity check
test_s = initial_states_t[:4]
test_a = torch.randn(4, ACTION_DIM, device=device)
test_grad = behavior_policy.grad_log_prob(test_s, test_a)
print(f"Behavior policy loaded. Test grad shape: {test_grad.shape}, magnitude: {test_grad.abs().mean():.4f}")
# Out:
# Behavior policy loaded. Test grad shape: torch.Size([4, 7]), magnitude: 445.7888

# %%
# ── Build paired real trajectory array for state-based logRMSE ──
real_states_list = []
for ep in target_data[:NUM_SYNTHETIC]:
    s = ep["states"]
    T = len(s)
    if T >= T_GEN:
        real_states_list.append(s[:T_GEN])
    else:
        padded = np.zeros((T_GEN, STATE_DIM), dtype=np.float32)
        padded[:T] = s
        padded[T:] = s[-1]
        real_states_list.append(padded)
real_states = np.array(real_states_list)
print(f"Real states for comparison: {real_states.shape}")
# Out:
# Real states for comparison: (50, 60, 19)

# %%
# ── Trajectory generator (positive + negative guidance) ──
def generate_trajectories(
    diffusion_model, initial_states,
    normalize_fn, unnormalize_fn,
    state_dim, action_dim, chunk_size, t_gen, device,
    target_scorer=None, behavior_scorer=None,
    alpha=0.0, lam=0.0, normalize_grad=True,
):
    """
    SOPE-style guided trajectory generation.
    guide = alpha * target_grad - lam * behavior_grad
    Applied to action dimensions only.
    """
    use_pos = (target_scorer is not None and alpha > 0)
    use_neg = (behavior_scorer is not None and lam > 0)
    guided = use_pos or use_neg
    B = initial_states.shape[0]
    td = state_dim + action_dim
    n_ts = diffusion_model.n_timesteps

    pad = torch.cat([initial_states, torch.zeros(B, action_dim, device=device)], 1)
    cond_init = normalize_fn(pad)[:, :state_dim]
    all_traj = torch.zeros(B, t_gen, td, device=device)
    conditions = {0: cond_init}
    total = 0

    while total < t_gen:
        x = torch.randn(B, chunk_size, td, device=device)
        x = apply_conditioning(x, conditions, state_dim)

        for t_d in reversed(range(n_ts)):
            t_t = torch.full((B,), t_d, device=device, dtype=torch.long)
            with torch.no_grad():
                mm, _, mlv = diffusion_model.p_mean_variance(x=x, t=t_t)
                ms = torch.exp(0.5 * mlv)

            if guided:
                mm = unnormalize_fn(mm)
                sc = mm[:, :, :state_dim]
                ac = mm[:, :, state_dim:]

                # Positive guidance: grad_log_prob of target policy
                pos_grad = torch.zeros(B, chunk_size, action_dim, device=device)
                if use_pos:
                    tg = target_scorer.grad_log_prob_chunk(sc, ac)
                    if normalize_grad:
                        tg = tg / (tg.norm(dim=-1, keepdim=True) + 1e-6)
                    pos_grad = tg

                # Negative guidance: grad_log_prob of behavior policy
                neg_grad = torch.zeros(B, chunk_size, action_dim, device=device)
                if use_neg:
                    bg = behavior_scorer.grad_log_prob_chunk(sc, ac)
                    if normalize_grad:
                        bg = bg / (bg.norm(dim=-1, keepdim=True) + 1e-6)
                    neg_grad = bg

                # Combined: alpha * target - lam * behavior (independent scales)
                guide = torch.zeros_like(mm)
                guide[:, :, state_dim:] = alpha * pos_grad - lam * neg_grad
                mm = mm + guide

                mm = normalize_fn(mm)
                mm = apply_conditioning(mm, conditions, state_dim)
                mm = unnormalize_fn(mm)
                mm = normalize_fn(mm)

            noise = torch.randn_like(x)
            x = mm + (1 - (t_d == 0) * 1.0) * ms * noise
            x = apply_conditioning(x, conditions, state_dim)

        chunk_u = unnormalize_fn(x)
        n_store = min(chunk_size - 1, t_gen - total)
        all_traj[:, total:total+n_store] = chunk_u[:, 1:1+n_store]
        total += n_store

        if total < t_gen:
            last_state_norm = x[:, -1, :state_dim]
            conditions = {0: last_state_norm}

    return all_traj.cpu().numpy()

print("Generator ready (positive + negative guidance).")
# Out:
# Generator ready (positive + negative guidance).

# %%
# ── Pre-load all target scorers (load each checkpoint once) ──
target_scorers = {}
for pol in TARGET_POLICIES:
    name = pol["name"]
    run_dir = CKPT_BASE / pol["dir"]
    print(f"Loading {name}...", end=" ", flush=True)
    t0 = time.time()
    ckpt = load_checkpoint(run_dir, ckpt_path=Path(pol["ckpt"]))
    target_algo = build_algo_from_checkpoint(ckpt, device=str(device))
    target_scorers[name] = RobomimicDiffusionScorer(
        target_algo, device=str(device), score_timestep=SCORE_TIMESTEP, obs_keys=OBS_KEYS
    )
    print(f"{time.time()-t0:.0f}s")
print(f"\nAll {len(target_scorers)} scorers loaded.")
# Out:
# Loading 50demos_epoch10...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:01:56] INFO     build_algo_from_checkpoint took 0.45 seconds to execute                           ]8;id=397936;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=597282;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 27s
# Loading 10demos_epoch10...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:06] INFO     build_algo_from_checkpoint took 0.38 seconds to execute                           ]8;id=977073;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=374553;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 10s
# Loading 200demos_epoch10...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:18] INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=692555;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=409885;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 11s
# Loading 200demos_epoch20...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:28] INFO     build_algo_from_checkpoint took 0.37 seconds to execute                           ]8;id=354767;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=458905;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 10s
# Loading 100demos_epoch20...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:37] INFO     build_algo_from_checkpoint took 0.37 seconds to execute                           ]8;id=22391;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=84666;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 10s
# Loading test_checkpoint...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:47] INFO     build_algo_from_checkpoint took 0.37 seconds to execute                           ]8;id=923636;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=802839;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 10s
# Loading 50demos_epoch20...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:52] INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=343356;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=188717;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 5s
# Loading 10demos_epoch30...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:54] INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=351074;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=117035;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 2s
# Loading 100demos_epoch30...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:56] INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=453929;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=97892;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 1s
# Loading 50demos_epoch30...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:57] INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=6658;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=510728;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 1s
# Loading 50demos_epoch40...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
#            INFO     build_algo_from_checkpoint took 0.36 seconds to execute                           ]8;id=478022;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=931670;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 1s
# Loading 200demos_epoch40...
# ============= Initialized Observation Utils with Obs Spec =============
#
# using obs modality: low_dim with keys: ['robot0_gripper_qpos', 'object', 'robot0_eef_quat', 'robot0_eef_pos']
# using obs modality: rgb with keys: []
# using obs modality: depth with keys: []
# using obs modality: scan with keys: []
# number of parameters: 6.576359e+07
# [16:02:58] INFO     build_algo_from_checkpoint took 0.42 seconds to execute                           ]8;id=10656;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py\common.py]8;;\:]8;id=648936;file:///home1/reishuen/latent_sope/src/latent_sope/utils/common.py#137\137]8;;\
# 1s
#
# All 12 scorers loaded.

# %%
# ── Generate unguided baseline (once) ──
print("Generating unguided trajectories...")
np.random.seed(42)
torch.manual_seed(42)
t0 = time.time()
unguided_trajs = generate_trajectories(
    diffusion_model=ema.ema_model, initial_states=initial_states_t,
    normalize_fn=normalize_fn, unnormalize_fn=unnormalize_fn,
    state_dim=STATE_DIM, action_dim=ACTION_DIM,
    chunk_size=CHUNK_SIZE, t_gen=T_GEN, device=device,
)
unguided_states = unguided_trajs[:, :, :STATE_DIM]
unguided_sr = compute_sr_hard(unguided_states)
unguided_hard = compute_ope_hard(unguided_states, GAMMA)
unguided_sigm = compute_ope_sigmoid(unguided_states, GAMMA)
unguided_per_traj_mse = np.mean((real_states - unguided_states) ** 2, axis=(1, 2))
unguided_state_rmse = np.sqrt(np.mean(unguided_per_traj_mse))
unguided_state_log_rmse = np.log(unguided_state_rmse + 1e-8)
print(f"Unguided: SR={unguided_sr*100:.0f}%, hard={unguided_hard.mean():.3f}, "
      f"sigmoid={unguided_sigm.mean():.3f}, state_logRMSE={unguided_state_log_rmse:.4f}, {time.time()-t0:.0f}s")
# Out:
# Generating unguided trajectories...
# Unguided: SR=60%, hard=5.020, sigmoid=7.992, state_logRMSE=-2.4772, 30s

# %%
# ── Sweep: (alpha, ratio) design points x target_policy ──
sweep_results = {}  # key: (design_idx, policy_name)
t0_all = time.time()
total_runs = len(DESIGN_POINTS) * len(TARGET_POLICIES)
run_count = 0

for di, (alpha, ratio) in enumerate(DESIGN_POINTS):
    lam = alpha * ratio
    print(f"\n{'='*80}")
    print(f"DESIGN POINT {di+1}/{len(DESIGN_POINTS)}: alpha={alpha:.2f}, ratio={ratio:.2f}, lam={lam:.3f}")
    print(f"{'='*80}")

    for pol in TARGET_POLICIES:
        name = pol["name"]
        run_count += 1
        oracle_sr = oracle_sr_map[name]

        print(f"  [{run_count}/{total_runs}] {name} (oracle={oracle_sr*100:.0f}%)...", end=" ", flush=True)
        np.random.seed(42)
        torch.manual_seed(42)
        t0 = time.time()

        guided_trajs = generate_trajectories(
            diffusion_model=ema.ema_model, initial_states=initial_states_t,
            normalize_fn=normalize_fn, unnormalize_fn=unnormalize_fn,
            state_dim=STATE_DIM, action_dim=ACTION_DIM,
            chunk_size=CHUNK_SIZE, t_gen=T_GEN, device=device,
            target_scorer=target_scorers[name],
            behavior_scorer=behavior_policy,
            alpha=alpha, lam=lam,
            normalize_grad=True,
        )
        gen_time = time.time() - t0

        guided_states = guided_trajs[:, :, :STATE_DIM]
        sr = compute_sr_hard(guided_states)
        ope_hard = float(compute_ope_hard(guided_states, GAMMA).mean())
        ope_sigm = float(compute_ope_sigmoid(guided_states, GAMMA).mean())

        per_traj_mse = np.mean((real_states - guided_states) ** 2, axis=(1, 2))
        state_rmse = np.sqrt(np.mean(per_traj_mse))
        state_log_rmse = np.log(state_rmse + 1e-8)

        sweep_results[(di, name)] = {
            "alpha": alpha,
            "ratio": ratio,
            "lam": lam,
            "oracle_sr": oracle_sr,
            "guided_sr": sr,
            "ope_hard": ope_hard,
            "ope_sigmoid": ope_sigm,
            "state_rmse": state_rmse,
            "state_log_rmse": state_log_rmse,
        }
        print(f"{gen_time:.0f}s -- SR={sr*100:.0f}%, hard={ope_hard:.3f}, sigm={ope_sigm:.3f}, logRMSE={state_log_rmse:.4f}")

total_time = time.time() - t0_all
print(f"\nTotal sweep: {total_time:.0f}s ({total_time/60:.1f} min)")
# Out:
# ================================================================================
# DESIGN POINT 1/15: alpha=0.14, ratio=0.00, lam=0.000
# ================================================================================
#   [1/180] 50demos_epoch10 (oracle=0%)...
# 69s -- SR=28%, hard=0.820, sigm=4.299, logRMSE=-2.2466
#   [2/180] 10demos_epoch10 (oracle=8%)...
# 69s -- SR=26%, hard=0.640, sigm=4.047, logRMSE=-2.2255
#   [3/180] 200demos_epoch10 (oracle=18%)...
# 69s -- SR=42%, hard=2.040, sigm=5.415, logRMSE=-2.4569
#   [4/180] 200demos_epoch20 (oracle=24%)...
# 69s -- SR=52%, hard=3.100, sigm=6.212, logRMSE=-2.5676
#   [5/180] 100demos_epoch20 (oracle=42%)...
# 69s -- SR=54%, hard=1.560, sigm=5.409, logRMSE=-2.6035
#   [6/180] test_checkpoint (oracle=54%)...
# 69s -- SR=44%, hard=2.060, sigm=5.676, logRMSE=-2.5657
#   [7/180] 50demos_epoch20 (oracle=60%)...
# 69s -- SR=74%, hard=3.560, sigm=7.071, logRMSE=-2.2950
#   [8/180] 10demos_epoch30 (oracle=62%)...
# 69s -- SR=80%, hard=4.480, sigm=7.528, logRMSE=-2.3970
#   [9/180] 100demos_epoch30 (oracle=72%)...
# 69s -- SR=46%, hard=1.740, sigm=5.227, logRMSE=-2.4781
#   [10/180] 50demos_epoch30 (oracle=82%)...
# 69s -- SR=70%, hard=2.940, sigm=6.464, logRMSE=-2.4195
#   [11/180] 50demos_epoch40 (oracle=88%)...
# 69s -- SR=60%, hard=2.600, sigm=6.251, logRMSE=-2.4436
#   [12/180] 200demos_epoch40 (oracle=90%)...
# 69s -- SR=40%, hard=1.440, sigm=4.899, logRMSE=-2.4879
#
# ================================================================================
# DESIGN POINT 2/15: alpha=0.11, ratio=0.65, lam=0.072
# ================================================================================
#   [13/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=6%, hard=0.180, sigm=3.614, logRMSE=-1.5910
#   [14/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=14%, hard=0.180, sigm=3.357, logRMSE=-2.1679
#   [15/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=66%, hard=3.560, sigm=6.760, logRMSE=-2.0257
#   [16/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=62%, hard=5.500, sigm=8.206, logRMSE=-2.1232
#   [17/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=42%, hard=0.980, sigm=4.858, logRMSE=-2.2938
#   [18/180] test_checkpoint (oracle=54%)...
# 70s -- SR=40%, hard=1.660, sigm=5.305, logRMSE=-2.1621
#   [19/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=84%, hard=3.840, sigm=7.165, logRMSE=-2.0836
#   [20/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=68%, hard=2.240, sigm=6.203, logRMSE=-2.2412
#   [21/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=48%, hard=1.900, sigm=5.393, logRMSE=-2.2454
#   [22/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=68%, hard=2.700, sigm=6.707, logRMSE=-2.1148
#   [23/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=88%, hard=3.320, sigm=7.093, logRMSE=-2.1781
#   [24/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=52%, hard=1.860, sigm=5.377, logRMSE=-2.1006
#
# ================================================================================
# DESIGN POINT 3/15: alpha=0.15, ratio=0.16, lam=0.024
# ================================================================================
#   [25/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=18%, hard=0.400, sigm=3.945, logRMSE=-2.0123
#   [26/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=16%, hard=0.200, sigm=3.603, logRMSE=-2.2362
#   [27/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=44%, hard=2.140, sigm=5.438, logRMSE=-2.3865
#   [28/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=44%, hard=2.240, sigm=5.535, logRMSE=-2.3441
#   [29/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=32%, hard=0.920, sigm=4.880, logRMSE=-2.6192
#   [30/180] test_checkpoint (oracle=54%)...
# 70s -- SR=34%, hard=1.020, sigm=4.961, logRMSE=-2.4793
#   [31/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=50%, hard=1.940, sigm=5.652, logRMSE=-2.3356
#   [32/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=80%, hard=3.460, sigm=6.853, logRMSE=-2.5002
#   [33/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=42%, hard=1.440, sigm=4.985, logRMSE=-2.4079
#   [34/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=66%, hard=2.980, sigm=6.544, logRMSE=-2.3002
#   [35/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=62%, hard=2.740, sigm=6.377, logRMSE=-2.3482
#   [36/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=32%, hard=1.180, sigm=4.690, logRMSE=-2.3861
#
# ================================================================================
# DESIGN POINT 4/15: alpha=0.18, ratio=0.30, lam=0.054
# ================================================================================
#   [37/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=12%, hard=0.280, sigm=3.654, logRMSE=-1.8654
#   [38/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=8%, hard=0.140, sigm=3.462, logRMSE=-2.2297
#   [39/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=46%, hard=2.000, sigm=5.416, logRMSE=-2.3881
#   [40/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=50%, hard=2.280, sigm=5.648, logRMSE=-2.2682
#   [41/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=28%, hard=0.800, sigm=4.736, logRMSE=-2.5210
#   [42/180] test_checkpoint (oracle=54%)...
# 70s -- SR=30%, hard=0.880, sigm=4.670, logRMSE=-2.4694
#   [43/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=50%, hard=1.560, sigm=5.533, logRMSE=-2.3204
#   [44/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=80%, hard=3.060, sigm=6.424, logRMSE=-2.6793
#   [45/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=44%, hard=1.120, sigm=4.798, logRMSE=-2.4078
#   [46/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=62%, hard=2.520, sigm=6.431, logRMSE=-2.1920
#   [47/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=60%, hard=2.700, sigm=6.466, logRMSE=-2.2736
#   [48/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=34%, hard=1.180, sigm=5.059, logRMSE=-2.4462
#
# ================================================================================
# DESIGN POINT 5/15: alpha=0.22, ratio=0.90, lam=0.198
# ================================================================================
#   [49/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=78%, hard=3.480, sigm=6.796, logRMSE=-1.5512
#   [50/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=2.619, logRMSE=-1.6209
#   [51/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=100%, hard=3.580, sigm=9.211, logRMSE=-1.6294
#   [52/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=92%, hard=6.100, sigm=9.861, logRMSE=-1.6755
#   [53/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=34%, hard=0.940, sigm=4.324, logRMSE=-1.6631
#   [54/180] test_checkpoint (oracle=54%)...
# 70s -- SR=22%, hard=0.540, sigm=4.024, logRMSE=-1.6494
#   [55/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=96%, hard=5.600, sigm=9.192, logRMSE=-1.7237
#   [56/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=34%, hard=0.580, sigm=5.049, logRMSE=-1.7118
#   [57/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=16%, hard=0.220, sigm=3.577, logRMSE=-1.6599
#   [58/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=100%, hard=4.960, sigm=9.492, logRMSE=-1.6923
#   [59/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=100%, hard=4.940, sigm=9.325, logRMSE=-1.6882
#   [60/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=26%, hard=0.560, sigm=4.192, logRMSE=-1.6397
#
# ================================================================================
# DESIGN POINT 6/15: alpha=0.24, ratio=0.41, lam=0.098
# ================================================================================
#   [61/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=2%, hard=0.020, sigm=3.406, logRMSE=-1.6760
#   [62/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=3.111, logRMSE=-2.2217
#   [63/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=44%, hard=2.180, sigm=5.460, logRMSE=-2.1364
#   [64/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=50%, hard=2.520, sigm=5.883, logRMSE=-2.1562
#   [65/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=20%, hard=0.340, sigm=4.056, logRMSE=-2.3783
#   [66/180] test_checkpoint (oracle=54%)...
# 70s -- SR=20%, hard=0.280, sigm=4.043, logRMSE=-2.4478
#   [67/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=70%, hard=3.260, sigm=6.691, logRMSE=-2.1983
#   [68/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=66%, hard=2.100, sigm=5.608, logRMSE=-2.2935
#   [69/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=42%, hard=1.140, sigm=4.701, logRMSE=-2.2828
#   [70/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=70%, hard=2.400, sigm=6.629, logRMSE=-2.1592
#   [71/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=72%, hard=2.380, sigm=6.438, logRMSE=-2.2518
#   [72/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=32%, hard=0.820, sigm=4.514, logRMSE=-2.2628
#
# ================================================================================
# DESIGN POINT 7/15: alpha=0.26, ratio=0.53, lam=0.138
# ================================================================================
#   [73/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=2%, hard=0.020, sigm=3.354, logRMSE=-1.6439
#   [74/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=3.004, logRMSE=-2.0815
#   [75/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=92%, hard=6.140, sigm=8.665, logRMSE=-1.9049
#   [76/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=58%, hard=3.820, sigm=6.895, logRMSE=-2.0877
#   [77/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=24%, hard=0.560, sigm=3.943, logRMSE=-2.2309
#   [78/180] test_checkpoint (oracle=54%)...
# 70s -- SR=26%, hard=0.660, sigm=3.979, logRMSE=-2.1833
#   [79/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=84%, hard=4.420, sigm=7.820, logRMSE=-2.0050
#   [80/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=58%, hard=1.520, sigm=5.347, logRMSE=-2.2773
#   [81/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=30%, hard=0.900, sigm=4.226, logRMSE=-2.1266
#   [82/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=68%, hard=3.420, sigm=7.344, logRMSE=-2.1904
#   [83/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=80%, hard=3.300, sigm=7.124, logRMSE=-2.2313
#   [84/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=46%, hard=1.180, sigm=4.719, logRMSE=-2.2623
#
# ================================================================================
# DESIGN POINT 8/15: alpha=0.29, ratio=0.68, lam=0.197
# ================================================================================
#   [85/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=28%, hard=1.280, sigm=4.190, logRMSE=-1.6265
#   [86/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=2.751, logRMSE=-1.8204
#   [87/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=100%, hard=10.920, sigm=12.370, logRMSE=-1.7060
#   [88/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=72%, hard=8.420, sigm=10.449, logRMSE=-1.8228
#   [89/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=52%, hard=2.200, sigm=5.482, logRMSE=-1.8001
#   [90/180] test_checkpoint (oracle=54%)...
# 70s -- SR=40%, hard=1.120, sigm=4.606, logRMSE=-1.8054
#   [91/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=86%, hard=7.460, sigm=10.294, logRMSE=-1.7725
#   [92/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=54%, hard=1.300, sigm=5.391, logRMSE=-1.8862
#   [93/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=8%, hard=0.440, sigm=3.247, logRMSE=-1.9293
#   [94/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=76%, hard=4.800, sigm=9.221, logRMSE=-1.8488
#   [95/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=82%, hard=4.920, sigm=8.608, logRMSE=-1.8087
#   [96/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=34%, hard=2.260, sigm=5.169, logRMSE=-1.8049
#
# ================================================================================
# DESIGN POINT 9/15: alpha=0.33, ratio=0.23, lam=0.076
# ================================================================================
#   [97/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=0%, hard=0.000, sigm=3.543, logRMSE=-1.7175
#   [98/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=2%, hard=0.020, sigm=3.296, logRMSE=-2.1920
#   [99/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=32%, hard=1.220, sigm=4.702, logRMSE=-2.2311
#   [100/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=42%, hard=1.640, sigm=5.177, logRMSE=-2.1103
#   [101/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=30%, hard=0.660, sigm=4.321, logRMSE=-2.4783
#   [102/180] test_checkpoint (oracle=54%)...
# 70s -- SR=24%, hard=0.660, sigm=4.317, logRMSE=-2.2885
#   [103/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=62%, hard=1.900, sigm=5.701, logRMSE=-2.2576
#   [104/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=78%, hard=3.300, sigm=6.548, logRMSE=-2.4628
#   [105/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=26%, hard=0.540, sigm=4.021, logRMSE=-2.4547
#   [106/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=56%, hard=2.460, sigm=6.421, logRMSE=-2.1042
#   [107/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=56%, hard=1.280, sigm=5.509, logRMSE=-2.3148
#   [108/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=22%, hard=0.700, sigm=4.223, logRMSE=-2.3752
#
# ================================================================================
# DESIGN POINT 10/15: alpha=0.35, ratio=0.79, lam=0.276
# ================================================================================
#   [109/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=88%, hard=4.500, sigm=8.123, logRMSE=-1.5439
#   [110/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=2.514, logRMSE=-1.6153
#   [111/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=96%, hard=3.380, sigm=10.053, logRMSE=-1.5915
#   [112/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=86%, hard=4.840, sigm=9.611, logRMSE=-1.6568
#   [113/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=12%, hard=0.380, sigm=3.796, logRMSE=-1.6499
#   [114/180] test_checkpoint (oracle=54%)...
# 70s -- SR=6%, hard=0.060, sigm=3.373, logRMSE=-1.5752
#   [115/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=100%, hard=7.300, sigm=11.014, logRMSE=-1.6584
#   [116/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=22%, hard=0.340, sigm=4.948, logRMSE=-1.6429
#   [117/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=22%, hard=0.560, sigm=3.937, logRMSE=-1.5934
#   [118/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=100%, hard=5.860, sigm=10.504, logRMSE=-1.6911
#   [119/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=94%, hard=4.200, sigm=10.412, logRMSE=-1.6742
#   [120/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=40%, hard=0.680, sigm=4.632, logRMSE=-1.5999
#
# ================================================================================
# DESIGN POINT 11/15: alpha=0.38, ratio=0.11, lam=0.042
# ================================================================================
#   [121/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=2%, hard=0.020, sigm=3.596, logRMSE=-1.8619
#   [122/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=8%, hard=0.120, sigm=3.422, logRMSE=-2.1601
#   [123/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=32%, hard=1.260, sigm=4.700, logRMSE=-2.1478
#   [124/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=34%, hard=1.260, sigm=4.652, logRMSE=-2.3944
#   [125/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=24%, hard=0.680, sigm=4.451, logRMSE=-2.4409
#   [126/180] test_checkpoint (oracle=54%)...
# 70s -- SR=18%, hard=0.380, sigm=4.184, logRMSE=-2.6078
#   [127/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=64%, hard=2.420, sigm=6.084, logRMSE=-2.2791
#   [128/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=80%, hard=3.040, sigm=6.510, logRMSE=-2.3198
#   [129/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=24%, hard=0.400, sigm=3.868, logRMSE=-2.6195
#   [130/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=58%, hard=2.180, sigm=6.041, logRMSE=-2.2874
#   [131/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=66%, hard=2.240, sigm=6.186, logRMSE=-2.1586
#   [132/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=18%, hard=0.740, sigm=4.136, logRMSE=-2.5806
#
# ================================================================================
# DESIGN POINT 12/15: alpha=0.42, ratio=0.35, lam=0.147
# ================================================================================
#   [133/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=0%, hard=0.000, sigm=3.406, logRMSE=-1.6176
#   [134/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=3.090, logRMSE=-2.0671
#   [135/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=68%, hard=3.040, sigm=6.496, logRMSE=-2.0093
#   [136/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=46%, hard=2.640, sigm=5.809, logRMSE=-2.1275
#   [137/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=14%, hard=0.380, sigm=3.956, logRMSE=-2.3078
#   [138/180] test_checkpoint (oracle=54%)...
# 70s -- SR=12%, hard=0.160, sigm=3.848, logRMSE=-2.4023
#   [139/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=80%, hard=2.680, sigm=6.582, logRMSE=-2.0802
#   [140/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=64%, hard=2.080, sigm=5.772, logRMSE=-2.2534
#   [141/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=20%, hard=0.420, sigm=3.823, logRMSE=-2.1537
#   [142/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=74%, hard=2.640, sigm=6.901, logRMSE=-2.1524
#   [143/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=68%, hard=2.520, sigm=6.821, logRMSE=-2.1689
#   [144/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=34%, hard=0.480, sigm=4.181, logRMSE=-2.3215
#
# ================================================================================
# DESIGN POINT 13/15: alpha=0.42, ratio=0.97, lam=0.407
# ================================================================================
#   [145/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=0%, hard=0.000, sigm=5.478, logRMSE=-1.5983
#   [146/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=2.762, logRMSE=-1.5458
#   [147/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=0%, hard=0.000, sigm=7.108, logRMSE=-1.5890
#   [148/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=0%, hard=0.000, sigm=3.692, logRMSE=-1.6546
#   [149/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=0%, hard=0.000, sigm=3.079, logRMSE=-1.6641
#   [150/180] test_checkpoint (oracle=54%)...
# 70s -- SR=0%, hard=0.000, sigm=3.129, logRMSE=-1.6421
#   [151/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=0%, hard=0.000, sigm=4.639, logRMSE=-1.6511
#   [152/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=16%, hard=0.160, sigm=4.714, logRMSE=-1.6481
#   [153/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=0%, hard=0.000, sigm=3.028, logRMSE=-1.6526
#   [154/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=0%, hard=0.000, sigm=3.669, logRMSE=-1.6921
#   [155/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=0%, hard=0.000, sigm=3.822, logRMSE=-1.6780
#   [156/180] 200demos_epoch40 (oracle=90%)...
# 70s -- SR=0%, hard=0.000, sigm=3.663, logRMSE=-1.6724
#
# ================================================================================
# DESIGN POINT 14/15: alpha=0.47, ratio=0.82, lam=0.385
# ================================================================================
#   [157/180] 50demos_epoch10 (oracle=0%)...
# 70s -- SR=22%, hard=0.300, sigm=6.673, logRMSE=-1.5925
#   [158/180] 10demos_epoch10 (oracle=8%)...
# 70s -- SR=0%, hard=0.000, sigm=2.360, logRMSE=-1.4485
#   [159/180] 200demos_epoch10 (oracle=18%)...
# 70s -- SR=4%, hard=0.040, sigm=8.164, logRMSE=-1.5783
#   [160/180] 200demos_epoch20 (oracle=24%)...
# 70s -- SR=6%, hard=0.100, sigm=4.575, logRMSE=-1.6580
#   [161/180] 100demos_epoch20 (oracle=42%)...
# 70s -- SR=0%, hard=0.000, sigm=3.242, logRMSE=-1.6518
#   [162/180] test_checkpoint (oracle=54%)...
# 70s -- SR=0%, hard=0.000, sigm=2.988, logRMSE=-1.6063
#   [163/180] 50demos_epoch20 (oracle=60%)...
# 70s -- SR=56%, hard=0.840, sigm=6.706, logRMSE=-1.6531
#   [164/180] 10demos_epoch30 (oracle=62%)...
# 70s -- SR=12%, hard=0.140, sigm=4.825, logRMSE=-1.5967
#   [165/180] 100demos_epoch30 (oracle=72%)...
# 70s -- SR=0%, hard=0.000, sigm=3.024, logRMSE=-1.6313
#   [166/180] 50demos_epoch30 (oracle=82%)...
# 70s -- SR=12%, hard=0.140, sigm=5.373, logRMSE=-1.6678
#   [167/180] 50demos_epoch40 (oracle=88%)...
# 70s -- SR=8%, hard=0.120, sigm=5.669, logRMSE=-1.6694
#   [168/180] 200demos_epoch40 (oracle=90%)...
# 72s -- SR=0%, hard=0.000, sigm=3.537, logRMSE=-1.6664
#
# ================================================================================
# DESIGN POINT 15/15: alpha=0.49, ratio=0.50, lam=0.245
# ================================================================================
#   [169/180] 50demos_epoch10 (oracle=0%)...
# 77s -- SR=20%, hard=1.360, sigm=4.204, logRMSE=-1.5866
#   [170/180] 10demos_epoch10 (oracle=8%)...
# 77s -- SR=0%, hard=0.000, sigm=2.897, logRMSE=-1.7924
#   [171/180] 200demos_epoch10 (oracle=18%)...
# 77s -- SR=94%, hard=5.100, sigm=10.032, logRMSE=-1.7109
#   [172/180] 200demos_epoch20 (oracle=24%)...
# 77s -- SR=82%, hard=7.580, sigm=10.040, logRMSE=-1.9646
#   [173/180] 100demos_epoch20 (oracle=42%)...
# 77s -- SR=56%, hard=1.920, sigm=5.304, logRMSE=-1.8055
#   [174/180] test_checkpoint (oracle=54%)...
# 77s -- SR=18%, hard=0.400, sigm=3.629, logRMSE=-1.7698
#   [175/180] 50demos_epoch20 (oracle=60%)...
# 77s -- SR=88%, hard=8.380, sigm=11.258, logRMSE=-1.7948
#   [176/180] 10demos_epoch30 (oracle=62%)...
# 76s -- SR=62%, hard=1.820, sigm=5.752, logRMSE=-1.8715
#   [177/180] 100demos_epoch30 (oracle=72%)...
# 75s -- SR=6%, hard=0.180, sigm=3.053, logRMSE=-1.8933
#   [178/180] 50demos_epoch30 (oracle=82%)...
# 73s -- SR=86%, hard=5.080, sigm=9.210, logRMSE=-1.7718
#   [179/180] 50demos_epoch40 (oracle=88%)...
# 76s -- SR=76%, hard=3.720, sigm=7.704, logRMSE=-1.8923
#   [180/180] 200demos_epoch40 (oracle=90%)...
# 76s -- SR=48%, hard=1.780, sigm=5.128, logRMSE=-1.8767
#
# Total sweep: 12656s (210.9 min)

# %%
# ── Compute metrics per design point ──
policy_names = [p["name"] for p in TARGET_POLICIES]
oracle_srs = np.array([oracle_sr_map[n] for n in policy_names])

design_metrics = {}
for di, (alpha, ratio) in enumerate(DESIGN_POINTS):
    lam = alpha * ratio
    opes_hard = np.array([sweep_results[(di, n)]["ope_hard"] for n in policy_names])
    opes_sigm = np.array([sweep_results[(di, n)]["ope_sigmoid"] for n in policy_names])
    guided_srs = np.array([sweep_results[(di, n)]["guided_sr"] for n in policy_names])

    opes_hard_norm = opes_hard / T_GEN
    opes_sigm_norm = opes_sigm / T_GEN

    rho_h, p_h = stats.spearmanr(oracle_srs, opes_hard)
    rho_s, p_s = stats.spearmanr(oracle_srs, opes_sigm)

    eps = 1e-6
    rmse_h = np.sqrt(np.mean((oracle_srs - opes_hard_norm) ** 2))
    rmse_s = np.sqrt(np.mean((oracle_srs - opes_sigm_norm) ** 2))
    log_rmse_h = np.sqrt(np.mean((np.log(oracle_srs + eps) - np.log(opes_hard_norm + eps)) ** 2))
    log_rmse_s = np.sqrt(np.mean((np.log(oracle_srs + eps) - np.log(opes_sigm_norm + eps)) ** 2))

    state_log_rmses = np.array([sweep_results[(di, n)]["state_log_rmse"] for n in policy_names])
    mean_state_log_rmse = float(np.mean(state_log_rmses))

    def regret_at_k(oracle_vals, ope_vals, k):
        true_topk = np.argsort(oracle_vals)[-k:]
        est_topk = np.argsort(ope_vals)[-k:]
        return float(oracle_vals[true_topk].mean() - oracle_vals[est_topk].mean())

    design_metrics[di] = {
        "alpha": alpha, "ratio": ratio, "lam": lam,
        "rho_hard": rho_h, "rho_sigm": rho_s,
        "rmse_hard": rmse_h, "rmse_sigm": rmse_s,
        "log_rmse_hard": log_rmse_h, "log_rmse_sigm": log_rmse_s,
        "regret1_hard": regret_at_k(oracle_srs, opes_hard, 1),
        "regret3_hard": regret_at_k(oracle_srs, opes_hard, 3),
        "regret1_sigm": regret_at_k(oracle_srs, opes_sigm, 1),
        "regret3_sigm": regret_at_k(oracle_srs, opes_sigm, 3),
        "mean_state_log_rmse": mean_state_log_rmse,
    }

print("Metrics computed for all design points.")
# Out:
# Metrics computed for all design points.

# %%
# ── Summary table ──
print("=" * 130)
print("v0.3.2.5c: ALPHA x LAMBDA LHS SWEEP (15 Maximin LHS points, 12 policies)")
print("=" * 130)

# Per-design-point per-policy table
for di, (alpha, ratio) in enumerate(DESIGN_POINTS):
    m = design_metrics[di]
    lam = alpha * ratio
    print(f"\n--- #{di+1}: alpha={alpha:.2f}, ratio={ratio:.2f}, lam={lam:.3f} | rho_hard={m['rho_hard']:+.3f} rho_sigm={m['rho_sigm']:+.3f} ---")
    for name in policy_names:
        r = sweep_results[(di, name)]
        print(f"  {name:<22} oracle={r['oracle_sr']*100:>5.0f}%  SR={r['guided_sr']*100:>5.0f}%  "
              f"hard={r['ope_hard']:>6.3f}  sigm={r['ope_sigmoid']:>6.3f}  logRMSE={r['state_log_rmse']:>7.4f}")

# Aggregate comparison
print("\n" + "=" * 130)
print("AGGREGATE METRICS BY DESIGN POINT")
print("=" * 130)
col_hdr = ("{:<4} {:>5} {:>5} {:>6} {:>7} {:>7} {:>8} {:>8} "
           "{:>10} {:>10} {:>10} {:>7} {:>7} {:>7} {:>7}").format(
    "#", "alpha", "ratio", "lam", "rho_H", "rho_S", "RMSE_H", "RMSE_S",
    "logRMSE_H", "logRMSE_S", "stateLogR", "R@1_H", "R@3_H", "R@1_S", "R@3_S")
print("\n" + col_hdr)
print("-" * 130)
for di in range(len(DESIGN_POINTS)):
    m = design_metrics[di]
    print(f"{di+1:<4} {m['alpha']:>5.2f} {m['ratio']:>5.2f} {m['lam']:>6.3f} "
          f"{m['rho_hard']:>+7.3f} {m['rho_sigm']:>+7.3f} "
          f"{m['rmse_hard']:>8.4f} {m['rmse_sigm']:>8.4f} "
          f"{m['log_rmse_hard']:>10.4f} {m['log_rmse_sigm']:>10.4f} "
          f"{m['mean_state_log_rmse']:>10.4f} "
          f"{m['regret1_hard']:>7.3f} {m['regret3_hard']:>7.3f} "
          f"{m['regret1_sigm']:>7.3f} {m['regret3_sigm']:>7.3f}")

best_di = max(range(len(DESIGN_POINTS)), key=lambda i: design_metrics[i]["rho_hard"])
best_m = design_metrics[best_di]
print(f"\nBest (by rho_hard): #{best_di+1} alpha={best_m['alpha']:.2f}, ratio={best_m['ratio']:.2f}, "
      f"lam={best_m['lam']:.3f} -> rho={best_m['rho_hard']:+.3f}")
# Out:
# ==================================================================================================================================
# v0.3.2.5c: ALPHA x LAMBDA LHS SWEEP (15 Maximin LHS points, 12 policies)
# ==================================================================================================================================
#
# --- #1: alpha=0.14, ratio=0.00, lam=0.000 | rho_hard=+0.343 rho_sigm=+0.406 ---
#   50demos_epoch10        oracle=    0%  SR=   28%  hard= 0.820  sigm= 4.299  logRMSE=-2.2466
#   10demos_epoch10        oracle=    8%  SR=   26%  hard= 0.640  sigm= 4.047  logRMSE=-2.2255
#   200demos_epoch10       oracle=   18%  SR=   42%  hard= 2.040  sigm= 5.415  logRMSE=-2.4569
#   200demos_epoch20       oracle=   24%  SR=   52%  hard= 3.100  sigm= 6.212  logRMSE=-2.5676
#   100demos_epoch20       oracle=   42%  SR=   54%  hard= 1.560  sigm= 5.409  logRMSE=-2.6035
#   test_checkpoint        oracle=   54%  SR=   44%  hard= 2.060  sigm= 5.676  logRMSE=-2.5657
#   50demos_epoch20        oracle=   60%  SR=   74%  hard= 3.560  sigm= 7.071  logRMSE=-2.2950
#   10demos_epoch30        oracle=   62%  SR=   80%  hard= 4.480  sigm= 7.528  logRMSE=-2.3970
#   100demos_epoch30       oracle=   72%  SR=   46%  hard= 1.740  sigm= 5.227  logRMSE=-2.4781
#   50demos_epoch30        oracle=   82%  SR=   70%  hard= 2.940  sigm= 6.464  logRMSE=-2.4195
#   50demos_epoch40        oracle=   88%  SR=   60%  hard= 2.600  sigm= 6.251  logRMSE=-2.4436
#   200demos_epoch40       oracle=   90%  SR=   40%  hard= 1.440  sigm= 4.899  logRMSE=-2.4879
#
# --- #2: alpha=0.11, ratio=0.65, lam=0.072 | rho_hard=+0.284 rho_sigm=+0.336 ---
#   50demos_epoch10        oracle=    0%  SR=    6%  hard= 0.180  sigm= 3.614  logRMSE=-1.5910
#   10demos_epoch10        oracle=    8%  SR=   14%  hard= 0.180  sigm= 3.357  logRMSE=-2.1679
#   200demos_epoch10       oracle=   18%  SR=   66%  hard= 3.560  sigm= 6.760  logRMSE=-2.0257
#   200demos_epoch20       oracle=   24%  SR=   62%  hard= 5.500  sigm= 8.206  logRMSE=-2.1232
#   100demos_epoch20       oracle=   42%  SR=   42%  hard= 0.980  sigm= 4.858  logRMSE=-2.2938
#   test_checkpoint        oracle=   54%  SR=   40%  hard= 1.660  sigm= 5.305  logRMSE=-2.1621
#   50demos_epoch20        oracle=   60%  SR=   84%  hard= 3.840  sigm= 7.165  logRMSE=-2.0836
#   10demos_epoch30        oracle=   62%  SR=   68%  hard= 2.240  sigm= 6.203  logRMSE=-2.2412
#   100demos_epoch30       oracle=   72%  SR=   48%  hard= 1.900  sigm= 5.393  logRMSE=-2.2454
#   50demos_epoch30        oracle=   82%  SR=   68%  hard= 2.700  sigm= 6.707  logRMSE=-2.1148
#   50demos_epoch40        oracle=   88%  SR=   88%  hard= 3.320  sigm= 7.093  logRMSE=-2.1781
#   200demos_epoch40       oracle=   90%  SR=   52%  hard= 1.860  sigm= 5.377  logRMSE=-2.1006
#
# --- #3: alpha=0.15, ratio=0.16, lam=0.024 | rho_hard=+0.524 rho_sigm=+0.483 ---
#   50demos_epoch10        oracle=    0%  SR=   18%  hard= 0.400  sigm= 3.945  logRMSE=-2.0123
#   10demos_epoch10        oracle=    8%  SR=   16%  hard= 0.200  sigm= 3.603  logRMSE=-2.2362
#   200demos_epoch10       oracle=   18%  SR=   44%  hard= 2.140  sigm= 5.438  logRMSE=-2.3865
#   200demos_epoch20       oracle=   24%  SR=   44%  hard= 2.240  sigm= 5.535  logRMSE=-2.3441
#   100demos_epoch20       oracle=   42%  SR=   32%  hard= 0.920  sigm= 4.880  logRMSE=-2.6192
#   test_checkpoint        oracle=   54%  SR=   34%  hard= 1.020  sigm= 4.961  logRMSE=-2.4793
#   50demos_epoch20        oracle=   60%  SR=   50%  hard= 1.940  sigm= 5.652  logRMSE=-2.3356
#   10demos_epoch30        oracle=   62%  SR=   80%  hard= 3.460  sigm= 6.853  logRMSE=-2.5002
#   100demos_epoch30       oracle=   72%  SR=   42%  hard= 1.440  sigm= 4.985  logRMSE=-2.4079
#   50demos_epoch30        oracle=   82%  SR=   66%  hard= 2.980  sigm= 6.544  logRMSE=-2.3002
#   50demos_epoch40        oracle=   88%  SR=   62%  hard= 2.740  sigm= 6.377  logRMSE=-2.3482
#   200demos_epoch40       oracle=   90%  SR=   32%  hard= 1.180  sigm= 4.690  logRMSE=-2.3861
#
# --- #4: alpha=0.18, ratio=0.30, lam=0.054 | rho_hard=+0.552 rho_sigm=+0.608 ---
#   50demos_epoch10        oracle=    0%  SR=   12%  hard= 0.280  sigm= 3.654  logRMSE=-1.8654
#   10demos_epoch10        oracle=    8%  SR=    8%  hard= 0.140  sigm= 3.462  logRMSE=-2.2297
#   200demos_epoch10       oracle=   18%  SR=   46%  hard= 2.000  sigm= 5.416  logRMSE=-2.3881
#   200demos_epoch20       oracle=   24%  SR=   50%  hard= 2.280  sigm= 5.648  logRMSE=-2.2682
#   100demos_epoch20       oracle=   42%  SR=   28%  hard= 0.800  sigm= 4.736  logRMSE=-2.5210
#   test_checkpoint        oracle=   54%  SR=   30%  hard= 0.880  sigm= 4.670  logRMSE=-2.4694
#   50demos_epoch20        oracle=   60%  SR=   50%  hard= 1.560  sigm= 5.533  logRMSE=-2.3204
#   10demos_epoch30        oracle=   62%  SR=   80%  hard= 3.060  sigm= 6.424  logRMSE=-2.6793
#   100demos_epoch30       oracle=   72%  SR=   44%  hard= 1.120  sigm= 4.798  logRMSE=-2.4078
#   50demos_epoch30        oracle=   82%  SR=   62%  hard= 2.520  sigm= 6.431  logRMSE=-2.1920
#   50demos_epoch40        oracle=   88%  SR=   60%  hard= 2.700  sigm= 6.466  logRMSE=-2.2736
#   200demos_epoch40       oracle=   90%  SR=   34%  hard= 1.180  sigm= 5.059  logRMSE=-2.4462
#
# --- #5: alpha=0.22, ratio=0.90, lam=0.198 | rho_hard=+0.028 rho_sigm=+0.070 ---
#   50demos_epoch10        oracle=    0%  SR=   78%  hard= 3.480  sigm= 6.796  logRMSE=-1.5512
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.619  logRMSE=-1.6209
#   200demos_epoch10       oracle=   18%  SR=  100%  hard= 3.580  sigm= 9.211  logRMSE=-1.6294
#   200demos_epoch20       oracle=   24%  SR=   92%  hard= 6.100  sigm= 9.861  logRMSE=-1.6755
#   100demos_epoch20       oracle=   42%  SR=   34%  hard= 0.940  sigm= 4.324  logRMSE=-1.6631
#   test_checkpoint        oracle=   54%  SR=   22%  hard= 0.540  sigm= 4.024  logRMSE=-1.6494
#   50demos_epoch20        oracle=   60%  SR=   96%  hard= 5.600  sigm= 9.192  logRMSE=-1.7237
#   10demos_epoch30        oracle=   62%  SR=   34%  hard= 0.580  sigm= 5.049  logRMSE=-1.7118
#   100demos_epoch30       oracle=   72%  SR=   16%  hard= 0.220  sigm= 3.577  logRMSE=-1.6599
#   50demos_epoch30        oracle=   82%  SR=  100%  hard= 4.960  sigm= 9.492  logRMSE=-1.6923
#   50demos_epoch40        oracle=   88%  SR=  100%  hard= 4.940  sigm= 9.325  logRMSE=-1.6882
#   200demos_epoch40       oracle=   90%  SR=   26%  hard= 0.560  sigm= 4.192  logRMSE=-1.6397
#
# --- #6: alpha=0.24, ratio=0.41, lam=0.098 | rho_hard=+0.392 rho_sigm=+0.517 ---
#   50demos_epoch10        oracle=    0%  SR=    2%  hard= 0.020  sigm= 3.406  logRMSE=-1.6760
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 3.111  logRMSE=-2.2217
#   200demos_epoch10       oracle=   18%  SR=   44%  hard= 2.180  sigm= 5.460  logRMSE=-2.1364
#   200demos_epoch20       oracle=   24%  SR=   50%  hard= 2.520  sigm= 5.883  logRMSE=-2.1562
#   100demos_epoch20       oracle=   42%  SR=   20%  hard= 0.340  sigm= 4.056  logRMSE=-2.3783
#   test_checkpoint        oracle=   54%  SR=   20%  hard= 0.280  sigm= 4.043  logRMSE=-2.4478
#   50demos_epoch20        oracle=   60%  SR=   70%  hard= 3.260  sigm= 6.691  logRMSE=-2.1983
#   10demos_epoch30        oracle=   62%  SR=   66%  hard= 2.100  sigm= 5.608  logRMSE=-2.2935
#   100demos_epoch30       oracle=   72%  SR=   42%  hard= 1.140  sigm= 4.701  logRMSE=-2.2828
#   50demos_epoch30        oracle=   82%  SR=   70%  hard= 2.400  sigm= 6.629  logRMSE=-2.1592
#   50demos_epoch40        oracle=   88%  SR=   72%  hard= 2.380  sigm= 6.438  logRMSE=-2.2518
#   200demos_epoch40       oracle=   90%  SR=   32%  hard= 0.820  sigm= 4.514  logRMSE=-2.2628
#
# --- #7: alpha=0.26, ratio=0.53, lam=0.138 | rho_hard=+0.280 rho_sigm=+0.371 ---
#   50demos_epoch10        oracle=    0%  SR=    2%  hard= 0.020  sigm= 3.354  logRMSE=-1.6439
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 3.004  logRMSE=-2.0815
#   200demos_epoch10       oracle=   18%  SR=   92%  hard= 6.140  sigm= 8.665  logRMSE=-1.9049
#   200demos_epoch20       oracle=   24%  SR=   58%  hard= 3.820  sigm= 6.895  logRMSE=-2.0877
#   100demos_epoch20       oracle=   42%  SR=   24%  hard= 0.560  sigm= 3.943  logRMSE=-2.2309
#   test_checkpoint        oracle=   54%  SR=   26%  hard= 0.660  sigm= 3.979  logRMSE=-2.1833
#   50demos_epoch20        oracle=   60%  SR=   84%  hard= 4.420  sigm= 7.820  logRMSE=-2.0050
#   10demos_epoch30        oracle=   62%  SR=   58%  hard= 1.520  sigm= 5.347  logRMSE=-2.2773
#   100demos_epoch30       oracle=   72%  SR=   30%  hard= 0.900  sigm= 4.226  logRMSE=-2.1266
#   50demos_epoch30        oracle=   82%  SR=   68%  hard= 3.420  sigm= 7.344  logRMSE=-2.1904
#   50demos_epoch40        oracle=   88%  SR=   80%  hard= 3.300  sigm= 7.124  logRMSE=-2.2313
#   200demos_epoch40       oracle=   90%  SR=   46%  hard= 1.180  sigm= 4.719  logRMSE=-2.2623
#
# --- #8: alpha=0.29, ratio=0.68, lam=0.197 | rho_hard=+0.126 rho_sigm=+0.077 ---
#   50demos_epoch10        oracle=    0%  SR=   28%  hard= 1.280  sigm= 4.190  logRMSE=-1.6265
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.751  logRMSE=-1.8204
#   200demos_epoch10       oracle=   18%  SR=  100%  hard=10.920  sigm=12.370  logRMSE=-1.7060
#   200demos_epoch20       oracle=   24%  SR=   72%  hard= 8.420  sigm=10.449  logRMSE=-1.8228
#   100demos_epoch20       oracle=   42%  SR=   52%  hard= 2.200  sigm= 5.482  logRMSE=-1.8001
#   test_checkpoint        oracle=   54%  SR=   40%  hard= 1.120  sigm= 4.606  logRMSE=-1.8054
#   50demos_epoch20        oracle=   60%  SR=   86%  hard= 7.460  sigm=10.294  logRMSE=-1.7725
#   10demos_epoch30        oracle=   62%  SR=   54%  hard= 1.300  sigm= 5.391  logRMSE=-1.8862
#   100demos_epoch30       oracle=   72%  SR=    8%  hard= 0.440  sigm= 3.247  logRMSE=-1.9293
#   50demos_epoch30        oracle=   82%  SR=   76%  hard= 4.800  sigm= 9.221  logRMSE=-1.8488
#   50demos_epoch40        oracle=   88%  SR=   82%  hard= 4.920  sigm= 8.608  logRMSE=-1.8087
#   200demos_epoch40       oracle=   90%  SR=   34%  hard= 2.260  sigm= 5.169  logRMSE=-1.8049
#
# --- #9: alpha=0.33, ratio=0.23, lam=0.076 | rho_hard=+0.473 rho_sigm=+0.420 ---
#   50demos_epoch10        oracle=    0%  SR=    0%  hard= 0.000  sigm= 3.543  logRMSE=-1.7175
#   10demos_epoch10        oracle=    8%  SR=    2%  hard= 0.020  sigm= 3.296  logRMSE=-2.1920
#   200demos_epoch10       oracle=   18%  SR=   32%  hard= 1.220  sigm= 4.702  logRMSE=-2.2311
#   200demos_epoch20       oracle=   24%  SR=   42%  hard= 1.640  sigm= 5.177  logRMSE=-2.1103
#   100demos_epoch20       oracle=   42%  SR=   30%  hard= 0.660  sigm= 4.321  logRMSE=-2.4783
#   test_checkpoint        oracle=   54%  SR=   24%  hard= 0.660  sigm= 4.317  logRMSE=-2.2885
#   50demos_epoch20        oracle=   60%  SR=   62%  hard= 1.900  sigm= 5.701  logRMSE=-2.2576
#   10demos_epoch30        oracle=   62%  SR=   78%  hard= 3.300  sigm= 6.548  logRMSE=-2.4628
#   100demos_epoch30       oracle=   72%  SR=   26%  hard= 0.540  sigm= 4.021  logRMSE=-2.4547
#   50demos_epoch30        oracle=   82%  SR=   56%  hard= 2.460  sigm= 6.421  logRMSE=-2.1042
#   50demos_epoch40        oracle=   88%  SR=   56%  hard= 1.280  sigm= 5.509  logRMSE=-2.3148
#   200demos_epoch40       oracle=   90%  SR=   22%  hard= 0.700  sigm= 4.223  logRMSE=-2.3752
#
# --- #10: alpha=0.35, ratio=0.79, lam=0.276 | rho_hard=+0.140 rho_sigm=+0.252 ---
#   50demos_epoch10        oracle=    0%  SR=   88%  hard= 4.500  sigm= 8.123  logRMSE=-1.5439
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.514  logRMSE=-1.6153
#   200demos_epoch10       oracle=   18%  SR=   96%  hard= 3.380  sigm=10.053  logRMSE=-1.5915
#   200demos_epoch20       oracle=   24%  SR=   86%  hard= 4.840  sigm= 9.611  logRMSE=-1.6568
#   100demos_epoch20       oracle=   42%  SR=   12%  hard= 0.380  sigm= 3.796  logRMSE=-1.6499
#   test_checkpoint        oracle=   54%  SR=    6%  hard= 0.060  sigm= 3.373  logRMSE=-1.5752
#   50demos_epoch20        oracle=   60%  SR=  100%  hard= 7.300  sigm=11.014  logRMSE=-1.6584
#   10demos_epoch30        oracle=   62%  SR=   22%  hard= 0.340  sigm= 4.948  logRMSE=-1.6429
#   100demos_epoch30       oracle=   72%  SR=   22%  hard= 0.560  sigm= 3.937  logRMSE=-1.5934
#   50demos_epoch30        oracle=   82%  SR=  100%  hard= 5.860  sigm=10.504  logRMSE=-1.6911
#   50demos_epoch40        oracle=   88%  SR=   94%  hard= 4.200  sigm=10.412  logRMSE=-1.6742
#   200demos_epoch40       oracle=   90%  SR=   40%  hard= 0.680  sigm= 4.632  logRMSE=-1.5999
#
# --- #11: alpha=0.38, ratio=0.11, lam=0.042 | rho_hard=+0.522 rho_sigm=+0.427 ---
#   50demos_epoch10        oracle=    0%  SR=    2%  hard= 0.020  sigm= 3.596  logRMSE=-1.8619
#   10demos_epoch10        oracle=    8%  SR=    8%  hard= 0.120  sigm= 3.422  logRMSE=-2.1601
#   200demos_epoch10       oracle=   18%  SR=   32%  hard= 1.260  sigm= 4.700  logRMSE=-2.1478
#   200demos_epoch20       oracle=   24%  SR=   34%  hard= 1.260  sigm= 4.652  logRMSE=-2.3944
#   100demos_epoch20       oracle=   42%  SR=   24%  hard= 0.680  sigm= 4.451  logRMSE=-2.4409
#   test_checkpoint        oracle=   54%  SR=   18%  hard= 0.380  sigm= 4.184  logRMSE=-2.6078
#   50demos_epoch20        oracle=   60%  SR=   64%  hard= 2.420  sigm= 6.084  logRMSE=-2.2791
#   10demos_epoch30        oracle=   62%  SR=   80%  hard= 3.040  sigm= 6.510  logRMSE=-2.3198
#   100demos_epoch30       oracle=   72%  SR=   24%  hard= 0.400  sigm= 3.868  logRMSE=-2.6195
#   50demos_epoch30        oracle=   82%  SR=   58%  hard= 2.180  sigm= 6.041  logRMSE=-2.2874
#   50demos_epoch40        oracle=   88%  SR=   66%  hard= 2.240  sigm= 6.186  logRMSE=-2.1586
#   200demos_epoch40       oracle=   90%  SR=   18%  hard= 0.740  sigm= 4.136  logRMSE=-2.5806
#
# --- #12: alpha=0.42, ratio=0.35, lam=0.147 | rho_hard=+0.298 rho_sigm=+0.497 ---
#   50demos_epoch10        oracle=    0%  SR=    0%  hard= 0.000  sigm= 3.406  logRMSE=-1.6176
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 3.090  logRMSE=-2.0671
#   200demos_epoch10       oracle=   18%  SR=   68%  hard= 3.040  sigm= 6.496  logRMSE=-2.0093
#   200demos_epoch20       oracle=   24%  SR=   46%  hard= 2.640  sigm= 5.809  logRMSE=-2.1275
#   100demos_epoch20       oracle=   42%  SR=   14%  hard= 0.380  sigm= 3.956  logRMSE=-2.3078
#   test_checkpoint        oracle=   54%  SR=   12%  hard= 0.160  sigm= 3.848  logRMSE=-2.4023
#   50demos_epoch20        oracle=   60%  SR=   80%  hard= 2.680  sigm= 6.582  logRMSE=-2.0802
#   10demos_epoch30        oracle=   62%  SR=   64%  hard= 2.080  sigm= 5.772  logRMSE=-2.2534
#   100demos_epoch30       oracle=   72%  SR=   20%  hard= 0.420  sigm= 3.823  logRMSE=-2.1537
#   50demos_epoch30        oracle=   82%  SR=   74%  hard= 2.640  sigm= 6.901  logRMSE=-2.1524
#   50demos_epoch40        oracle=   88%  SR=   68%  hard= 2.520  sigm= 6.821  logRMSE=-2.1689
#   200demos_epoch40       oracle=   90%  SR=   34%  hard= 0.480  sigm= 4.181  logRMSE=-2.3215
#
# --- #13: alpha=0.42, ratio=0.97, lam=0.407 | rho_hard=+0.131 rho_sigm=-0.154 ---
#   50demos_epoch10        oracle=    0%  SR=    0%  hard= 0.000  sigm= 5.478  logRMSE=-1.5983
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.762  logRMSE=-1.5458
#   200demos_epoch10       oracle=   18%  SR=    0%  hard= 0.000  sigm= 7.108  logRMSE=-1.5890
#   200demos_epoch20       oracle=   24%  SR=    0%  hard= 0.000  sigm= 3.692  logRMSE=-1.6546
#   100demos_epoch20       oracle=   42%  SR=    0%  hard= 0.000  sigm= 3.079  logRMSE=-1.6641
#   test_checkpoint        oracle=   54%  SR=    0%  hard= 0.000  sigm= 3.129  logRMSE=-1.6421
#   50demos_epoch20        oracle=   60%  SR=    0%  hard= 0.000  sigm= 4.639  logRMSE=-1.6511
#   10demos_epoch30        oracle=   62%  SR=   16%  hard= 0.160  sigm= 4.714  logRMSE=-1.6481
#   100demos_epoch30       oracle=   72%  SR=    0%  hard= 0.000  sigm= 3.028  logRMSE=-1.6526
#   50demos_epoch30        oracle=   82%  SR=    0%  hard= 0.000  sigm= 3.669  logRMSE=-1.6921
#   50demos_epoch40        oracle=   88%  SR=    0%  hard= 0.000  sigm= 3.822  logRMSE=-1.6780
#   200demos_epoch40       oracle=   90%  SR=    0%  hard= 0.000  sigm= 3.663  logRMSE=-1.6724
#
# --- #14: alpha=0.47, ratio=0.82, lam=0.385 | rho_hard=-0.036 rho_sigm=-0.028 ---
#   50demos_epoch10        oracle=    0%  SR=   22%  hard= 0.300  sigm= 6.673  logRMSE=-1.5925
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.360  logRMSE=-1.4485
#   200demos_epoch10       oracle=   18%  SR=    4%  hard= 0.040  sigm= 8.164  logRMSE=-1.5783
#   200demos_epoch20       oracle=   24%  SR=    6%  hard= 0.100  sigm= 4.575  logRMSE=-1.6580
#   100demos_epoch20       oracle=   42%  SR=    0%  hard= 0.000  sigm= 3.242  logRMSE=-1.6518
#   test_checkpoint        oracle=   54%  SR=    0%  hard= 0.000  sigm= 2.988  logRMSE=-1.6063
#   50demos_epoch20        oracle=   60%  SR=   56%  hard= 0.840  sigm= 6.706  logRMSE=-1.6531
#   10demos_epoch30        oracle=   62%  SR=   12%  hard= 0.140  sigm= 4.825  logRMSE=-1.5967
#   100demos_epoch30       oracle=   72%  SR=    0%  hard= 0.000  sigm= 3.024  logRMSE=-1.6313
#   50demos_epoch30        oracle=   82%  SR=   12%  hard= 0.140  sigm= 5.373  logRMSE=-1.6678
#   50demos_epoch40        oracle=   88%  SR=    8%  hard= 0.120  sigm= 5.669  logRMSE=-1.6694
#   200demos_epoch40       oracle=   90%  SR=    0%  hard= 0.000  sigm= 3.537  logRMSE=-1.6664
#
# --- #15: alpha=0.49, ratio=0.50, lam=0.245 | rho_hard=+0.098 rho_sigm=+0.119 ---
#   50demos_epoch10        oracle=    0%  SR=   20%  hard= 1.360  sigm= 4.204  logRMSE=-1.5866
#   10demos_epoch10        oracle=    8%  SR=    0%  hard= 0.000  sigm= 2.897  logRMSE=-1.7924
#   200demos_epoch10       oracle=   18%  SR=   94%  hard= 5.100  sigm=10.032  logRMSE=-1.7109
#   200demos_epoch20       oracle=   24%  SR=   82%  hard= 7.580  sigm=10.040  logRMSE=-1.9646
#   100demos_epoch20       oracle=   42%  SR=   56%  hard= 1.920  sigm= 5.304  logRMSE=-1.8055
#   test_checkpoint        oracle=   54%  SR=   18%  hard= 0.400  sigm= 3.629  logRMSE=-1.7698
#   50demos_epoch20        oracle=   60%  SR=   88%  hard= 8.380  sigm=11.258  logRMSE=-1.7948
#   10demos_epoch30        oracle=   62%  SR=   62%  hard= 1.820  sigm= 5.752  logRMSE=-1.8715
#   100demos_epoch30       oracle=   72%  SR=    6%  hard= 0.180  sigm= 3.053  logRMSE=-1.8933
#   50demos_epoch30        oracle=   82%  SR=   86%  hard= 5.080  sigm= 9.210  logRMSE=-1.7718
#   50demos_epoch40        oracle=   88%  SR=   76%  hard= 3.720  sigm= 7.704  logRMSE=-1.8923
#   200demos_epoch40       oracle=   90%  SR=   48%  hard= 1.780  sigm= 5.128  logRMSE=-1.8767
#
# ==================================================================================================================================
# AGGREGATE METRICS BY DESIGN POINT
# ==================================================================================================================================
#
# #    alpha ratio    lam   rho_H   rho_S   RMSE_H   RMSE_S  logRMSE_H  logRMSE_S  stateLogR   R@1_H   R@3_H   R@1_S   R@3_S
# ----------------------------------------------------------------------------------------------------------------------------------
# 1     0.14  0.00  0.000  +0.343  +0.406   0.5479   0.4996     3.7137     3.6020    -2.4322   0.280   0.380   0.280   0.187
# 2     0.11  0.65  0.072  +0.284  +0.336   0.5481   0.4976     3.4941     3.5502    -2.1106   0.660   0.527   0.660   0.293
# 3     0.15  0.16  0.024  +0.524  +0.483   0.5547   0.5046     3.8035     3.6080    -2.3630   0.280   0.093   0.280   0.093
# 4     0.18  0.30  0.054  +0.552  +0.608   0.5577   0.5053     3.8377     3.5935    -2.3384   0.280   0.093   0.020   0.093
# 5     0.22  0.90  0.198  +0.028  +0.070   0.5481   0.4950     5.4597     3.7386    -1.6588   0.660   0.313   0.660   0.220
# 6     0.24  0.41  0.098  +0.392  +0.517   0.5595   0.5073     4.7562     3.5927    -2.2054   0.300   0.313   0.300   0.100
# 7     0.26  0.53  0.138  +0.280  +0.371   0.5521   0.5030     4.5825     3.5732    -2.1021   0.720   0.527   0.720   0.333
# 8     0.29  0.68  0.197  +0.126  +0.077   0.5366   0.4908     5.0022     3.5890    -1.8026   0.720   0.527   0.720   0.527
# 9     0.33  0.23  0.076  +0.473  +0.420   0.5631   0.5114     3.4559     3.6234    -2.2489   0.280   0.187   0.280   0.187
# 10    0.35  0.79  0.276  +0.140  +0.252   0.5472   0.4891     5.6768     3.7768    -1.6244   0.300   0.313   0.300   0.100
# 11    0.38  0.11  0.042  +0.522  +0.427   0.5620   0.5110     3.7006     3.6277    -2.3215   0.280   0.167   0.280   0.167
# 12    0.42  0.35  0.147  +0.298  +0.497   0.5613   0.5083     4.6042     3.6045    -2.1385   0.720   0.333   0.080   0.100
# 13    0.42  0.97  0.407  +0.131  -0.154   0.5831   0.5307    11.9672     3.8631    -1.6407   0.280   0.087   0.720   0.600
# 14    0.47  0.82  0.385  -0.036  -0.028   0.5814   0.5206     9.5063     3.8532    -1.6183   0.300   0.393   0.720   0.607
# 15    0.49  0.50  0.245  +0.098  +0.119   0.5404   0.4930     5.1644     3.6056    -1.8109   0.300   0.527   0.300   0.527
#
# Best (by rho_hard): #4 alpha=0.18, ratio=0.30, lam=0.054 -> rho=+0.552

# %%
# ── Figure 1: Metrics over (alpha, ratio) design space ──
fig, axes = plt.subplots(2, 2, figsize=(14, 12))

alphas = np.array([design_metrics[i]["alpha"] for i in range(len(DESIGN_POINTS))])
ratios = np.array([design_metrics[i]["ratio"] for i in range(len(DESIGN_POINTS))])

metrics_to_plot = [
    ("rho_hard", "Spearman rho (hard)", "RdYlGn", True),
    ("rho_sigm", "Spearman rho (sigmoid)", "RdYlGn", True),
    ("rmse_hard", "RMSE (hard)", "RdYlGn_r", False),
    ("mean_state_log_rmse", "State log(RMSE)", "RdYlGn_r", False),
]

for ax, (key, title, cmap, higher_better) in zip(axes.flat, metrics_to_plot):
    vals = np.array([design_metrics[i][key] for i in range(len(DESIGN_POINTS))])
    sc = ax.scatter(alphas, ratios, c=vals, cmap=cmap, s=200, edgecolor="black", zorder=5)
    for i in range(len(DESIGN_POINTS)):
        ax.annotate(f"{vals[i]:.3f}", (alphas[i], ratios[i]),
                    textcoords="offset points", xytext=(6, 6), fontsize=7)
    plt.colorbar(sc, ax=ax)
    # Mark best point
    best_i = np.argmax(vals) if higher_better else np.argmin(vals)
    ax.scatter([alphas[best_i]], [ratios[best_i]], s=300, facecolors="none",
              edgecolors="red", linewidths=2, zorder=6)
    ax.set_xlabel("Alpha")
    ax.set_ylabel("Ratio (lam / alpha)")
    ax.set_title(title)
    ax.set_xlim(0.05, 0.55)
    ax.set_ylim(-0.05, 1.05)
    ax.grid(True, alpha=0.2)

fig.suptitle("v0.3.2.5c: Metrics over (alpha, ratio) Design Space", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Figure 2: OPE scatter for best/worst design points ──
sorted_by_rho = sorted(range(len(DESIGN_POINTS)), key=lambda i: design_metrics[i]["rho_hard"], reverse=True)
show_indices = sorted_by_rho[:3] + sorted_by_rho[-3:]  # top 3 + bottom 3

fig, axes = plt.subplots(1, len(show_indices), figsize=(4*len(show_indices), 4), sharey=True)

for ax, di in zip(axes, show_indices):
    m = design_metrics[di]
    opes = np.array([sweep_results[(di, n)]["ope_hard"] / T_GEN for n in policy_names])
    ax.scatter(oracle_srs * 100, opes * 100, s=80, c="coral", edgecolor="black", zorder=5)
    ax.plot([0, 100], [0, 100], "k--", alpha=0.3)
    for j, n in enumerate(policy_names):
        label = n.replace("demos_epoch", "e").replace("test_checkpoint", "test")
        ax.annotate(label, (oracle_srs[j]*100, opes[j]*100),
                    textcoords="offset points", xytext=(3, 3), fontsize=5)
    ax.set_xlabel("Oracle (%)")
    ax.set_title(f"#{di+1}: a={m['alpha']:.2f} r={m['ratio']:.2f}\nrho={m['rho_hard']:+.3f}", fontsize=9)
    ax.grid(True, alpha=0.3)
    ax.set_xlim(-5, 100)
    ax.set_ylim(-5, 100)

axes[0].set_ylabel("OPE Hard (normalized %)")
fig.suptitle("v0.3.2.5c: OPE vs Oracle — Best 3 + Worst 3 Design Points", fontsize=12, fontweight="bold")
plt.tight_layout()
plt.show()

# %%
# ── Figure 3: State logRMSE across design space ──
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Panel 1: logRMSE vs rho_hard (tradeoff)
ax = axes[0]
rhos = np.array([design_metrics[i]["rho_hard"] for i in range(len(DESIGN_POINTS))])
lrs = np.array([design_metrics[i]["mean_state_log_rmse"] for i in range(len(DESIGN_POINTS))])
ax.scatter(rhos, lrs, s=100, c=ratios, cmap="coolwarm", edgecolor="black", zorder=5)
for i in range(len(DESIGN_POINTS)):
    ax.annotate(f"a={alphas[i]:.2f}\nr={ratios[i]:.2f}", (rhos[i], lrs[i]),
                textcoords="offset points", xytext=(5, 5), fontsize=6)
ax.axhline(unguided_state_log_rmse, color="gray", ls="--", alpha=0.7, label=f"Unguided ({unguided_state_log_rmse:.3f})")
sc = ax.scatter(rhos, lrs, s=100, c=ratios, cmap="coolwarm", edgecolor="black", zorder=5)
plt.colorbar(sc, ax=ax, label="Ratio")
ax.set_xlabel("Spearman rho (hard)")
ax.set_ylabel("State log(RMSE)")
ax.set_title("Rank Correlation vs Trajectory Realism")
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)

# Panel 2: logRMSE colored by alpha
ax = axes[1]
sc = ax.scatter(alphas, lrs, s=100, c=ratios, cmap="coolwarm", edgecolor="black", zorder=5)
for i in range(len(DESIGN_POINTS)):
    ax.annotate(f"r={ratios[i]:.2f}", (alphas[i], lrs[i]),
                textcoords="offset points", xytext=(5, 5), fontsize=7)
ax.axhline(unguided_state_log_rmse, color="gray", ls="--", alpha=0.7, label="Unguided")
plt.colorbar(sc, ax=ax, label="Ratio")
ax.set_xlabel("Alpha")
ax.set_ylabel("State log(RMSE)")
ax.set_title("State logRMSE vs Alpha (colored by ratio)")
ax.legend(fontsize=8)
ax.grid(True, alpha=0.3)

fig.suptitle("v0.3.2.5c: State-based logRMSE", fontsize=14, fontweight="bold")
plt.tight_layout()
plt.show()
